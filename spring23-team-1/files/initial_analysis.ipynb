# %%
import pandas as pd

#Ramps_0.csv
ramps_0_df = pd.read_csv("../data/Ramps_0.csv")

#Roadway_Centerline_2.csv
roadway_df = pd.read_csv("../data/Roadway_Centerline_2.csv")

#Sidewalk_Hazards_1.csv.csv
hazards_df = pd.read_csv("../data/Sidewalk_Hazards_1.csv")

#Sidewalks_3.csv
sidewalks_df = pd.read_csv("../data/Sidewalks_3.csv")

# %%
ramps_0_df.head()
# Out:
#    FID  ObjectID  ObjectID_1     CREEC_Type       CREEC_Posi  \
# 0    1      1249        1249       Parallel  Uni-Directional
# 1    2       823         823       Parallel  Uni-Directional
# 2    3      1250        1250  Perpendicular  Uni-Directional
# 3    4       824         824       Parallel  Uni-Directional
# 4    5      1251        1251  Perpendicular  Uni-Directional
#
#                   RAMP_MATL  THR_WIDTH LAND_EXIST  LANDING_SL  \
# 0  Portland Cement Concrete        4.0        Yes         2.3
# 1  Portland Cement Concrete        4.0        Yes         9.7
# 2  Portland Cement Concrete        4.5        Yes         1.9
# 3  Portland Cement Concrete        4.0                    0.0
# 4  Portland Cement Concrete        5.0        Yes         2.5
#
#                                           LANDING_CO  ...  I_NEARFID  PARC_ID  \
# 0                               Excellent (Like new)  ...       5824
# 1  Fair (Minor/Hairline damage with no impact to ...  ...       3021
# ...

# %%
roadway_df.head()
# Out:
#    FID  PARENT STATUS  LENGTH         GREENBOOK             HIGHWAY  GIS  \
# 0    1  ENNIS1            392          Ennis Rd            ENNIS RD    1
# 1    2  COMMO4            500         Common St           COMMON ST    1
# 2    3  ENTER1           1132     Enterprise St       ENTERPRISE ST    1
# 3    4  HARLE1            612         Harlem St           HARLEM ST    1
# 4    5  COMMO5          29000  Commonwealth Ave  COMMONWEALTH AV EB    1
#
#    JURISDICTI QC_NOTE FUN_CLASS GRID  MIN_STATIO  MAX_STATIO  COUNCIL  \
# 0  PUBLIC WAY                LO    0           0         392        7
# 1  PUBLIC WAY                LO    0           0         500        1
# 2  PUBLIC WAY                LO    0           0        1132        2
# 3  PUBLIC WAY                LO    0           0         612        4
# 4  PUBLIC WAY                AR    0           0       29000        9
#
#            DISTRICT1           District  NO_LABEL RTE_SYS_ED  Shape__Length
# ...

# %%
hazards_df.head()
# Out:
#    FID                                   Type  \
# 0    1  Fixed pinch point <36” sidewalk width
# 1    2     Trip hazards not due to tree roots
# 2    3     Trip hazards not due to tree roots
# 3    4     Trip hazards not due to tree roots
# 4    5     Trip hazards not due to tree roots
#
#                                GlobalID             CreationDa  \
# 0  cc67f93c-a292-4062-936c-47f67aebed17   8/7/2020 12:00:00 AM
# 1  99d4c4f2-3ad6-466f-b4c0-47c516262904  5/27/2020 12:00:00 AM
# 2  5c8f0a22-619e-4cd6-a5bb-960b79ca7d49   8/7/2020 12:00:00 AM
# 3  9aa27356-f282-4ab5-867d-0df0f295487c  5/27/2020 12:00:00 AM
# 4  2ecf85c5-20e6-44d5-bdb4-61588510993e  5/27/2020 12:00:00 AM
#
#                            Creator               EditDate  \
# 0          Enmanuel.Raposo_stantec   8/7/2020 12:00:00 AM
# 1          Enmanuel.Raposo_stantec  5/27/2020 12:00:00 AM
# 2          Enmanuel.Raposo_stantec   8/7/2020 12:00:00 AM
# 3  Victor.Vega@stantec.com_stantec  5/27/2020 12:00:00 AM
# ...

# %%
sidewalks_df.head()
# Out:
#    FID SWK_ID MATERIAL SWK_WIDTH          DISTRICT SWK_AREA  PARENT  \
# 0    1      1       CC       5.5       CHARLESTOWN     3648  ALBIO1
# 1    2   1440       CC         8  SOUTH DORCHESTER     1296  ASHMO3
# 2    3    402       CC         6  SOUTH DORCHESTER     1671  ALMON1
# 3    4   1441       CC         8  SOUTH DORCHESTER     1313  ASHMO3
# 4    5    403       CC         6  SOUTH DORCHESTER     1351  ALMON1
#
#         SEG_ID   SIDE  CG_ID  Rpr_Yr  New_SCI Recon_Date  HPNETWORK  \
# 0     ALBIO1_0   LEFT  24842       0       85        NaN          0
# 1  ASHMO3_3808   LEFT   1433       0        0        NaN          1
# 2  ALMON1_1749   LEFT    401       0       55        NaN          1
# 3  ASHMO3_3452   LEFT   1434       0       63        NaN          1
# 4  ALMON1_2047  RIGHT    402       0       67        NaN          1
#
#    TEST_AREA  COST_RECON  GOODCANDID  TOTAREA  Shape__Area  Shape__Length
# ...
