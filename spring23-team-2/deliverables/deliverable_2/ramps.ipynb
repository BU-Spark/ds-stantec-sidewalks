# %%
import pandas as pd
ramps_df = pd.read_csv('data/Ramp_score.csv')
# Out:
# C:\Users\xiao\AppData\Local\Temp\ipykernel_28808\15277543.py:2: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   ramps_df = pd.read_csv('data/Ramp_score.csv')

# %%
ramps_df['properties.score_1']
# Out:
# 0        82.400000
# 1        92.800000
# 2        66.341154
# 3        95.975000
# 4        87.750000
#            ...
# 26207     0.000000
# 26208     0.000000
# 26209     0.000000
# 26210     0.000000
# 26211     0.000000
# Name: properties.score_1, Length: 26212, dtype: float64

# %%
ramps_df.columns
# Out:
# Index(['type', 'id', 'geometry.type', 'geometry.coordinates', 'properties.FID',
#        'properties.ObjectID_1', 'properties.ObjectID_2',
#        'properties.CREEC_Type', 'properties.CREEC_Posi',
#        'properties.RAMP_MATL', 'properties.THR_WIDTH', 'properties.LAND_EXIST',
#        'properties.LANDING_SL', 'properties.LANDING_CO', 'properties.APRON_SL',
#        'properties.LFLARE_SL', 'properties.DWP_MATL', 'properties.DWP_COND',
#        'properties.GUTTER_SL', 'properties.GUTTER_CS', 'properties.LIP',
#        'properties.CROSS_', 'properties.RFLARE_SL', 'properties.SAFE_ZONE_',
#        'properties.RAMP_OBSTR', 'properties.FLARE_OBST',
#        'properties.APRON_CROS', 'properties.Crosswalk_',
#        'properties.RAMP_COND', 'properties.ADA_Compli', 'properties.Photo',
#        'properties.NEAR_FID', 'properties.NEAR_DIST', 'properties.FID_1',
#        'properties.DESCRIPTIO', 'properties.INT_ID', 'properties.Failure_Ty',
#        'properties.score_1', 'properties.Fail_Label', 'properties.RampID_1'],
#       dtype='object')

# %%
# use rename method to remove "properties." prefix
ramps_df_new = ramps_df.rename(columns=lambda x: x.replace('properties.', ''))

# %%
ramps_df_new.head()
# Out:
#       type  id geometry.type                      geometry.coordinates  FID  \
# 0  Feature   0         Point   [-7911843.053800002, 5213855.430799998]    0
# 1  Feature   1         Point   [-7912104.434000002, 5213764.354100004]    1
# 2  Feature   2         Point  [-7912111.2201999985, 5213780.467799999]    2
# 3  Feature   3         Point    [-7912093.786999997, 5213788.37470001]    3
# 4  Feature   4         Point   [-7911853.312899999, 5213875.931500003]    4
#
#    ObjectID_1  ObjectID_2 CREEC_Type CREEC_Posi                 RAMP_MATL  \
# 0           1           1   Diagonal   Diagonal  Portland Cement Concrete
# 1           2           2   Diagonal   Diagonal  Portland Cement Concrete
# 2           3           3   Diagonal   Diagonal  Portland Cement Concrete
# 3           4           4   Diagonal   Diagonal  Portland Cement Concrete
# 4           5           5   Diagonal   Diagonal  Portland Cement Concrete
#
#    ...                                              Photo NEAR_FID  NEAR_DIST  \
# 0  ...  V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...     7579  17.798542
# 1  ...  V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...     7721  11.418106
# 2  ...  V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...     7721  12.922239
# 3  ...  V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...     7721  14.858769
# 4  ...  V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...     7579  15.310391
#
#   FID_1                 DESCRIPTIO  INT_ID                        Failure_Ty  \
# 0  7579   Berkeley St / Newbury St     904  Concrete FailurePvt/Cswk Failure
# 1  7721  Clarendon St / Newbury St    2233                  Pvt/Cswk Failure
# 2  7721  Clarendon St / Newbury St    2233  Concrete FailurePvt/Cswk Failure
# 3  7721  Clarendon St / Newbury St    2233                  Pvt/Cswk Failure
# 4  7579   Berkeley St / Newbury St     904  Concrete FailurePvt/Cswk Failure
#
#      score_1                                         Fail_Label  RampID_1
# 0  82.400000  Landing slope 4.6%; Gutter x-slope 3.2%; Cross...     904.2
# 1  92.800000                  Lip exists; Crosswalk misaligned;    2233.3
# 2  66.341154  Landing slope 2.9%; Apron slope 14%; Right fla...    2233.4
# 3  95.975000         Gutter x-slope 3.3%; Crosswalk misaligned;    2233.1
# 4  87.750000  Landing slope 2.1%; Gutter x-slope 4.5%; Cross...     904.1
#
# [5 rows x 40 columns]

# %%
ramps_df_old = pd.read_csv('data/Ramps_0_Updated.csv')
ramps_df_old.drop(columns ='Unnamed: 0', axis = 1, inplace = True)

# %%
ramps_df_old.head()
# Out:
#    FID  ObjectID  ObjectID_1     CREEC_Type       CREEC_Posi  \
# 0    1      1249        1249       Parallel  Uni-Directional
# 1    2       823         823       Parallel  Uni-Directional
# 2    3      1250        1250  Perpendicular  Uni-Directional
# 3    4       824         824       Parallel  Uni-Directional
# 4    5      1251        1251  Perpendicular  Uni-Directional
#
#                   RAMP_MATL  THR_WIDTH LAND_EXIST  LANDING_SL  \
# 0  Portland Cement Concrete        4.0        Yes         2.3
# 1  Portland Cement Concrete        4.0        Yes         9.7
# 2  Portland Cement Concrete        4.5        Yes         1.9
# 3  Portland Cement Concrete        4.0                    0.0
# 4  Portland Cement Concrete        5.0        Yes         2.5
#
#                                           LANDING_CO  ...  NEAR_ANGLE  \
# 0                               Excellent (Like new)  ...         0.0
# 1  Fair (Minor/Hairline damage with no impact to ...  ...         0.0
# 2                               Excellent (Like new)  ...         0.0
# 3                                                     ...         0.0
# 4  Fair (Minor/Hairline damage with no impact to ...  ...         0.0
#
#       Bearing Dwy RAMP_ID_1  Ramp_ID_d  Longitude   Latitude  \
# 0  255.310939        8998.1     8998.1 -71.165906  42.341852
# 1    3.625703        5999.1     5999.1 -71.055954  42.365543
# 2  147.404378        4375.2     4375.2 -71.137155  42.349207
# 3  265.705311        6880.1     6880.1 -71.055531  42.365034
# 4   70.955876        4375.1     4375.1 -71.137100  42.349289
#
#                                              address  postal neighborhood
# 0  Boston College (Brighton Campus), Undine Road,...   02138     Brighton
# 1  6, Margaret Street, North End, Boston, Suffolk...   02113    North End
# 2  132, Glenville Avenue, Allston Village, Allsto...   02134      Allston
# 3  1, Noyes Place, North End, Boston, Suffolk Cou...   02113    North End
# 4  139, Glenville Avenue, Allston Village, Allsto...   02134      Allston
#
# [5 rows x 47 columns]

# %%
# get the common columns using set intersection
common_columns = set(ramps_df_new.columns).intersection(set(ramps_df_old.columns))
common_columns_list = list(common_columns)
common_columns_list
# Out:
# ['NEAR_FID',
#  'FLARE_OBST',
#  'THR_WIDTH',
#  'GUTTER_CS',
#  'RAMP_COND',
#  'APRON_SL',
#  'RAMP_OBSTR',
#  'CREEC_Posi',
#  'APRON_CROS',
#  'RFLARE_SL',
#  'LIP',
#  'DWP_MATL',
#  'LANDING_SL',
#  'RAMP_MATL',
#  'Photo',
#  'Failure_Ty',
#  'ObjectID_1',
#  'LANDING_CO',
#  'CREEC_Type',
#  'INT_ID',
#  'CROSS_',
#  'NEAR_DIST',
#  'ADA_Compli',
#  'FID',
#  'GUTTER_SL',
#  'DWP_COND',
#  'SAFE_ZONE_',
#  'Crosswalk_',
#  'LFLARE_SL',
#  'LAND_EXIST']

# %%
ramps_df_old = ramps_df_old.sort_values('ObjectID_1')

# %%
# ramps_df_old[ramps_df_old['ObjectID'] != ramps_df_old['ObjectID_1']]
ramps_df_old[ramps_df_old['ObjectID'] != ramps_df_old['ObjectID_1']]
# Out:
#          FID  ObjectID  ObjectID_1 CREEC_Type CREEC_Posi RAMP_MATL  THR_WIDTH  \
# 25014  25015     21716           0                                        0.0
# 25015  25016     24078           0                                        0.0
#
#       LAND_EXIST  LANDING_SL LANDING_CO  ...  NEAR_ANGLE     Bearing Dwy  \
# 25014                    0.0             ...         0.0  111.523021
# 25015                    0.0             ...         0.0  128.729298
#
#       RAMP_ID_1  Ramp_ID_d  Longitude   Latitude  \
# 25014    5287.1     5287.1 -71.028339  42.365784
# 25015    1990.5     1990.5 -71.069411  42.356201
#
#                                                  address  postal neighborhood
# 25014  Meridian Food Market, Tomahawk Drive, Jeffries...   02128  East Boston
# 25015  Beacon Street, Beacon Hill, Boston, Suffolk Co...   02108  Beacon Hill
#
# [2 rows x 47 columns]

# %%
# Removing the objectID and ObjectID_1 mismatch records
ramps_df_old = ramps_df_old[ramps_df_old['ObjectID'] == ramps_df_old['ObjectID_1']]
ramps_df_old.head()
# Out:
#        FID  ObjectID  ObjectID_1 CREEC_Type CREEC_Posi  \
# 1175  1176         1           1   Diagonal   Diagonal
# 1210  1211         2           2   Diagonal   Diagonal
# 1211  1212         3           3   Diagonal   Diagonal
# 1212  1213         4           4   Diagonal   Diagonal
# 1213  1214         5           5   Diagonal   Diagonal
#
#                      RAMP_MATL  THR_WIDTH LAND_EXIST  LANDING_SL  \
# 1175  Portland Cement Concrete        5.0        Yes         4.6
# 1210  Portland Cement Concrete        5.0        Yes         0.7
# 1211  Portland Cement Concrete        5.0        Yes         2.9
# 1212  Portland Cement Concrete        5.0        Yes         1.1
# 1213  Portland Cement Concrete        4.5        Yes         2.1
#
#                                              LANDING_CO  ...  NEAR_ANGLE  \
# 1175  Fair (Minor/Hairline damage with no impact to ...  ...         0.0
# 1210                               Excellent (Like new)  ...         0.0
# 1211  Fair (Minor/Hairline damage with no impact to ...  ...         0.0
# 1212                               Excellent (Like new)  ...         0.0
# 1213                               Excellent (Like new)  ...         0.0
#
#          Bearing Dwy RAMP_ID_1  Ramp_ID_d  Longitude   Latitude  \
# 1175  111.498126         904.2      904.2 -71.073295  42.352009
# 1210  204.869440        2233.3     2233.3 -71.075643  42.351405
# 1211  296.326186        2233.4     2233.4 -71.075704  42.351512
# 1212   23.302030        2233.1     2233.1 -71.075548  42.351564
# 1213   24.348423         904.1      904.1 -71.073388  42.352145
#
#                                                 address  postal neighborhood
# 1175  Brooks Brothers, 46, Newbury Street, Back Bay,...   02116     Back Bay
# 1210  110, Newbury Street, Back Bay, Boston, Suffolk...   02116     Back Bay
# 1211  Cole Haan, 109, Newbury Street, Back Bay, Bost...   02116     Back Bay
# 1212  103-105, Newbury Street, Back Bay, Boston, Suf...   02116     Back Bay
# 1213  39-47, Newbury Street, Back Bay, Boston, Suffo...   02116     Back Bay
#
# [5 rows x 47 columns]

# %%
common_old = ['ObjectID', 'ObjectID_1', 'CREEC_Type', 'CREEC_Posi', 'RAMP_MATL', 'RAMP_COND', 'DWP_COND', 'CROSS_', 'Crosswalk_']
common_new = ['ObjectID_1', 'ObjectID_2', 'CREEC_Type', 'CREEC_Posi', 'RAMP_MATL', 'RAMP_COND', 'DWP_COND', 'CROSS_', 'Crosswalk_']
ramps_df_old.sort_values('ObjectID_1').head(10)[common_old]
# Out:
#       ObjectID  ObjectID_1     CREEC_Type       CREEC_Posi  \
# 1175         1           1       Diagonal         Diagonal
# 1210         2           2       Diagonal         Diagonal
# 1211         3           3       Diagonal         Diagonal
# 1212         4           4       Diagonal         Diagonal
# 1213         5           5       Diagonal         Diagonal
# 1214         6           6  Perpendicular  Uni-Directional
# 1215         7           7  Perpendicular  Uni-Directional
# 1216         8           8  Perpendicular  Uni-Directional
# 1217         9           9  Perpendicular  Uni-Directional
# 1218        10          10  Perpendicular  Uni-Directional
#
#                      RAMP_MATL  \
# 1175  Portland Cement Concrete
# 1210  Portland Cement Concrete
# 1211  Portland Cement Concrete
# 1212  Portland Cement Concrete
# 1213  Portland Cement Concrete
# 1214  Portland Cement Concrete
# 1215  Portland Cement Concrete
# 1216  Portland Cement Concrete
# 1217  Portland Cement Concrete
# 1218  Portland Cement Concrete
#
#                                               RAMP_COND  \
# 1175  Fair (Minor/Hairline damage with no impact to ...
# 1210                               Excellent (Like new)
# 1211  Fair (Minor/Hairline damage with no impact to ...
# 1212                               Excellent (Like new)
# 1213                               Excellent (Like new)
# 1214                               Excellent (Like new)
# 1215                               Excellent (Like new)
# 1216                               Excellent (Like new)
# 1217                               Excellent (Like new)
# 1218                               Excellent (Like new)
#
#                                                DWP_COND                CROSS_  \
# 1175  Fair (panel shows wear but still fully functio...  Crosswalk misaligned
# 1210                               Excellent (Like new)  Crosswalk misaligned
# 1211                               Excellent (Like new)  Crosswalk misaligned
# 1212                               Excellent (Like new)  Crosswalk misaligned
# 1213  Fair (panel shows wear but still fully functio...  Crosswalk misaligned
# 1214                               Excellent (Like new)     Crosswalk aligned
# 1215  Fair (panel shows wear but still fully functio...     Crosswalk aligned
# 1216  Fair (panel shows wear but still fully functio...     Crosswalk aligned
# 1217                               Excellent (Like new)     Crosswalk aligned
# 1218  Fair (panel shows wear but still fully functio...     Crosswalk aligned
#
#                          Crosswalk_
# 1175           Fair- slightly faded
# 1210           Fair- slightly faded
# 1211           Fair- slightly faded
# 1212           Fair- slightly faded
# 1213  Excellent- like new condition
# 1214           Fair- slightly faded
# 1215  Excellent- like new condition
# 1216           Fair- slightly faded
# 1217  Excellent- like new condition
# 1218  Excellent- like new condition

# %%
ramps_df_new = ramps_df_new.sort_values('ObjectID_1') #.head(10)[['ObjectID_1', 'ObjectID_2', 'CREEC_Type', 'CREEC_Posi', 'RAMP_MATL', 'RAMP_COND']]

# %%
ramps_df_new = ramps_df_new[ramps_df_new['ObjectID_1'] == ramps_df_new['ObjectID_2']]

# %%
ramps_df_new.head(10)[common_new]
# Out:
#    ObjectID_1  ObjectID_2     CREEC_Type       CREEC_Posi  \
# 0           1           1       Diagonal         Diagonal
# 1           2           2       Diagonal         Diagonal
# 2           3           3       Diagonal         Diagonal
# 3           4           4       Diagonal         Diagonal
# 4           5           5       Diagonal         Diagonal
# 5           6           6  Perpendicular  Uni-Directional
# 6           7           7  Perpendicular  Uni-Directional
# 7           8           8  Perpendicular  Uni-Directional
# 8           9           9  Perpendicular  Uni-Directional
# 9          10          10  Perpendicular  Uni-Directional
#
#                   RAMP_MATL  \
# 0  Portland Cement Concrete
# 1  Portland Cement Concrete
# 2  Portland Cement Concrete
# 3  Portland Cement Concrete
# 4  Portland Cement Concrete
# 5  Portland Cement Concrete
# 6  Portland Cement Concrete
# 7  Portland Cement Concrete
# 8  Portland Cement Concrete
# 9  Portland Cement Concrete
#
#                                            RAMP_COND  \
# 0  Fair (Minor/Hairline damage with no impact to ...
# 1                               Excellent (Like new)
# 2  Fair (Minor/Hairline damage with no impact to ...
# 3                               Excellent (Like new)
# 4                               Excellent (Like new)
# 5                               Excellent (Like new)
# 6                               Excellent (Like new)
# 7                               Excellent (Like new)
# 8                               Excellent (Like new)
# 9                               Excellent (Like new)
#
#                                             DWP_COND                CROSS_  \
# 0  Fair (panel shows wear but still fully functio...  Crosswalk misaligned
# 1                               Excellent (Like new)  Crosswalk misaligned
# 2                               Excellent (Like new)  Crosswalk misaligned
# 3                               Excellent (Like new)  Crosswalk misaligned
# 4  Fair (panel shows wear but still fully functio...  Crosswalk misaligned
# 5                               Excellent (Like new)     Crosswalk aligned
# 6  Fair (panel shows wear but still fully functio...     Crosswalk aligned
# 7  Fair (panel shows wear but still fully functio...     Crosswalk aligned
# 8                               Excellent (Like new)     Crosswalk aligned
# 9  Fair (panel shows wear but still fully functio...     Crosswalk aligned
#
#                       Crosswalk_
# 0           Fair- slightly faded
# 1           Fair- slightly faded
# 2           Fair- slightly faded
# 3           Fair- slightly faded
# 4  Excellent- like new condition
# 5           Fair- slightly faded
# 6  Excellent- like new condition
# 7           Fair- slightly faded
# 8  Excellent- like new condition
# 9  Excellent- like new condition

# %%
len(ramps_df_new.ObjectID_1)
# Out:
# 26161

# %%
len(ramps_df_old.ObjectID_1)
# Out:
# 26159

# %%
missing_ids = set(ramps_df_new['ObjectID_1']) - set(ramps_df_old['ObjectID_1'])
missing_ids
# Out:
# {21716, 24078}

# %%
ramps_df_old.iloc[21716]
# Out:
# FID                                                         21321
# ObjectID                                                    23687
# ObjectID_1                                                  23687
# CREEC_Type                                          Perpendicular
# CREEC_Posi                                        Uni-Directional
# RAMP_MATL                                Portland Cement Concrete
# THR_WIDTH                                                     4.0
# LAND_EXIST                                                    Yes
# LANDING_SL                                                    1.3
# LANDING_CO      Fair (Minor/Hairline damage with no impact to ...
# APRON_SL                                                      6.7
# LFLARE_SL                                                     9.2
# DWP_MATL                                         Plastic - Yellow
# DWP_COND        Fair (panel shows wear but still fully functio...
# GUTTER_SL                                                     2.2
# GUTTER_CS                                                     5.0
# LIP                                                            No
# CROSS_                                          Crosswalk aligned
# RFLARE_SL                                                     4.6
# SAFE_ZONE_                      Fair (pavement in fair condition)
# RAMP_OBSTR                                                     No
# FLARE_OBST                                                     No
# APRON_CROS                                                    1.4
# Crosswalk_                           Poor- needs to be re-striped
# RAMP_COND       Fair (Minor/Hairline damage with no impact to ...
# ADA_Compli                                          Not Compliant
# Photo           V:\1794\active\179410852\CREEC Ramps\CREEC_QC_...
# ObjectID_3                                                  23687
# Failure_Ty                                       Pvt/Cswk Failure
# Failure_La              gutter slope 2.2%Poor Condition Crosswalk
# NEAR_FID                                                       -1
# NEAR_DIST                                                    -1.0
# INT_ID                                                       2692
# I_NEARDIST                                              14.308991
# I_NEARFID                                                    5769
# PARC_ID
# AT_INT                                                          Y
# NEAR_ANGLE                                                    0.0
# Bearing                                                 240.65342
# Dwy
# RAMP_ID_1                                                  2692.4
# Ramp_ID_d                                                  2692.4
# Longitude                                              -71.098405
# Latitude                                                42.335077
# address         99, Cornelia Court, Mission Main, Mission Hill...
# postal                                                      02120
# neighborhood                                         Mission Hill
# Name: 21320, dtype: object

# %%
columns_to_match = ['ObjectID_1', 'CREEC_Type', 'CREEC_Posi', 'RAMP_MATL', 'RAMP_COND', 'DWP_COND', 'CROSS_', 'Crosswalk_']
merged_df = pd.merge(ramps_df_old, ramps_df_new[['score_1'] + columns_to_match], on=columns_to_match)

# %%
merged_df.head(2)
# Out:
#     FID  ObjectID  ObjectID_1 CREEC_Type CREEC_Posi                 RAMP_MATL  \
# 0  1176         1           1   Diagonal   Diagonal  Portland Cement Concrete
# 1  1211         2           2   Diagonal   Diagonal  Portland Cement Concrete
#
#    THR_WIDTH LAND_EXIST  LANDING_SL  \
# 0        5.0        Yes         4.6
# 1        5.0        Yes         0.7
#
#                                           LANDING_CO  ...     Bearing  Dwy  \
# 0  Fair (Minor/Hairline damage with no impact to ...  ...  111.498126
# 1                               Excellent (Like new)  ...  204.869440
#
#   RAMP_ID_1 Ramp_ID_d  Longitude   Latitude  \
# 0     904.2     904.2 -71.073295  42.352009
# 1    2233.3    2233.3 -71.075643  42.351405
#
#                                              address postal  neighborhood  \
# 0  Brooks Brothers, 46, Newbury Street, Back Bay,...  02116      Back Bay
# 1  110, Newbury Street, Back Bay, Boston, Suffolk...  02116      Back Bay
#
#   score_1
# 0    82.4
# 1    92.8
#
# [2 rows x 48 columns]

# %%
merged_df.to_csv('data/Ramps_with_score.csv')

# %%
df = pd.read_csv('data/Ramps_with_score.csv')
df.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)
df.head()
# Out:
#     FID  ObjectID  ObjectID_1 CREEC_Type CREEC_Posi                 RAMP_MATL  \
# 0  1176         1           1   Diagonal   Diagonal  Portland Cement Concrete
# 1  1211         2           2   Diagonal   Diagonal  Portland Cement Concrete
# 2  1212         3           3   Diagonal   Diagonal  Portland Cement Concrete
# 3  1213         4           4   Diagonal   Diagonal  Portland Cement Concrete
# 4  1214         5           5   Diagonal   Diagonal  Portland Cement Concrete
#
#    THR_WIDTH LAND_EXIST  LANDING_SL  \
# 0        5.0        Yes         4.6
# 1        5.0        Yes         0.7
# 2        5.0        Yes         2.9
# 3        5.0        Yes         1.1
# 4        4.5        Yes         2.1
#
#                                           LANDING_CO  ...     Bearing  Dwy  \
# 0  Fair (Minor/Hairline damage with no impact to ...  ...  111.498126
# 1                               Excellent (Like new)  ...  204.869440
# 2  Fair (Minor/Hairline damage with no impact to ...  ...  296.326186
# 3                               Excellent (Like new)  ...   23.302030
# 4                               Excellent (Like new)  ...   24.348423
#
#   RAMP_ID_1 Ramp_ID_d  Longitude   Latitude  \
# 0     904.2     904.2 -71.073295  42.352009
# 1    2233.3    2233.3 -71.075643  42.351405
# 2    2233.4    2233.4 -71.075704  42.351512
# 3    2233.1    2233.1 -71.075548  42.351564
# 4     904.1     904.1 -71.073388  42.352145
#
#                                              address postal  neighborhood  \
# 0  Brooks Brothers, 46, Newbury Street, Back Bay,...  02116      Back Bay
# 1  110, Newbury Street, Back Bay, Boston, Suffolk...  02116      Back Bay
# 2  Cole Haan, 109, Newbury Street, Back Bay, Bost...  02116      Back Bay
# 3  103-105, Newbury Street, Back Bay, Boston, Suf...  02116      Back Bay
# 4  39-47, Newbury Street, Back Bay, Boston, Suffo...  02116      Back Bay
#
#      score_1
# 0  82.400000
# 1  92.800000
# 2  66.341154
# 3  95.975000
# 4  87.750000
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Ramps_with_score is the sorted data with the ramps scores.

# %%
import pandas as pd
from folium import plugins, Map, CircleMarker
from folium.plugins import HeatMap
import geopandas as gpd
import folium
import geopy
import asyncio
from shapely.geometry import Polygon, Point
from pandas.io.json import json_normalize

sidewalks =gpd.read_file('data/shape/Ramps_Scored.shx')

# %%
geolocator = geopy.Nominatim(user_agent='my-application1')
async def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))

    return location.raw['address']

async def get_response(zipcodes):
    return await asyncio.gather(**zipcodes)
def process_sidewalks_hazards():
    data = folium.GeoJson(data=sidewalks["geometry"])
    coord = { "x" : [], "y" : [] }
    for i in range(len(data.data['features'])):
        
        coord["x"].append(float(data.data['features'][i]['geometry']['coordinates'][0]))
        coord["y"].append(float(data.data['features'][i]['geometry']['coordinates'][1]))    
    
    zipcodes = []
    for index,row in coord.iterrows():
        zipcodes.append(asyncio.ensure_future(get_zipcode(row, geolocator,lat_field='y', lon_field='x')))
    response = asyncio.run(get_response(zipcodes))
    sidewalks['address'] = response
    sidewalks['pincode'] = sidewalks['address'].apply(lambda x: x['postcode'])
    sidewalks.to_csv("data/sidewalks_ramps_withaddress.csv")

# %%
import folium
from folium import plugins, Map

map = folium.Map(location=[42.361145, -71.057083],zoom_start = 30)
data = folium.GeoJson(sidewalks['geometry'])
data.add_to(map)
map.save('maps/sidewalks/Sidewalks_ramps.html')

# %%
csv_file = pd.read_csv("data/Hospitals.csv")
csv_file['Latitude'] = csv_file['Latitude'].astype(float)
csv_file['Longitude'] = csv_file['Longitude'].astype(float)
csv_file.head()

for point in range(0, len(csv_file)):
    folium.CircleMarker([csv_file.iloc[point]['Longitude'], csv_file.iloc[point]['Latitude']],
                        color = "red", fill = True, 
                        fill_color = "red").add_to(map)


map.save('maps/sidewalks/Sidewalks_hospitals.html')
